# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("genz.csv", index_col=False)

# %% [markdown]
# ###Data Cleaning

# %%
df.head()
# Out:
#    age  gender    country  daily_usage_hours primary_platform  \
# 0   19    Male  Australia           2.658617         Snapchat
# 1   16  Female        USA           5.685387          Twitter
# 2   25  Female      India           2.782420           TikTok
# 3   27    Male      India           3.486598          YouTube
# 4   23  Female      India           3.748829           TikTok
#
#    num_platforms_used        purpose  avg_session_minutes  night_usage  \
# 0                   4      Education            29.222443            0
# 1                   3    Socializing            32.464726            1
# 2                   2    Socializing            18.170204            1
# 3                   4      Education            22.493804            1
# 4                   1  Entertainment            27.358410            1
#
#    mental_health_score addiction_level  screen_time_before_sleep
# 0             6.705830          Medium                 15.779443
# ...

# %%
df.shape
# Out:
# (1000000, 12)

# %%
df.isnull()
# Out:
#           age  gender  country  daily_usage_hours  primary_platform  \
# 0       False   False    False              False             False
# 1       False   False    False              False             False
# 2       False   False    False              False             False
# 3       False   False    False              False             False
# 4       False   False    False              False             False
# ...       ...     ...      ...                ...               ...
# 999995  False   False    False              False             False
# 999996  False   False    False              False             False
# 999997  False   False    False              False             False
# 999998  False   False    False              False             False
# 999999  False   False    False              False             False
#
#         num_platforms_used  purpose  avg_session_minutes  night_usage  \
# 0                    False    False                False        False
# ...

# %%
df.isnull().sum()
# Out:
# age                         0
# gender                      0
# country                     0
# daily_usage_hours           0
# primary_platform            0
# num_platforms_used          0
# purpose                     0
# avg_session_minutes         0
# night_usage                 0
# mental_health_score         0
# addiction_level             0
# screen_time_before_sleep    0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# User Engagement and product Strategy

# %% [markdown]
#         1 Which social media platform drives the highest daily engagement?

# %%
df.groupby('primary_platform')['daily_usage_hours'].max().sort_values(ascending=False)
# Out:
# primary_platform
# Instagram    10.000000
# YouTube      10.000000
# TikTok        9.915185
# Twitter       9.784525
# Snapchat      9.706301
# Name: daily_usage_hours, dtype: float64

# %% [markdown]
#     Do users with more platforms spend more total time or split attention ?

# %%
df.groupby('num_platforms_used')['daily_usage_hours'].mean()
# Out:
# num_platforms_used
# 1    3.520650
# 2    3.518742
# 3    3.514161
# 4    3.506981
# 5    3.514450
# Name: daily_usage_hours, dtype: float64

# %%
sns.catplot(x ='num_platforms_used' , y= 'daily_usage_hours', kind='bar' , data=df )
plt.show()

# %%
df.head()
# Out:
#    age  gender    country  daily_usage_hours primary_platform  \
# 0   19    Male  Australia           2.658617         Snapchat
# 1   16  Female        USA           5.685387          Twitter
# 2   25  Female      India           2.782420           TikTok
# 3   27    Male      India           3.486598          YouTube
# 4   23  Female      India           3.748829           TikTok
#
#    num_platforms_used        purpose  avg_session_minutes  night_usage  \
# 0                   4      Education            29.222443            0
# 1                   3    Socializing            32.464726            1
# 2                   2    Socializing            18.170204            1
# 3                   4      Education            22.493804            1
# 4                   1  Entertainment            27.358410            1
#
#    mental_health_score addiction_level  screen_time_before_sleep
# 0             6.705830          Medium                 15.779443
# ...

# %% [markdown]
# Which app people used the most whose addiction level is high ?

# %%
x=df[df['addiction_level']=='High']
# Out:
#         age  gender    country  daily_usage_hours primary_platform  \
# 1        16  Female        USA           5.685387          Twitter
# 6        25    Male    Germany           5.241584           TikTok
# 12       23  Female        USA           6.207281        Instagram
# 14       20    Male      India           5.160911        Instagram
# 16       16    Male  Australia           5.332598           TikTok
# ...     ...     ...        ...                ...              ...
# 999989   25    Male        USA           5.181593          YouTube
# 999991   24  Female         UK           5.516207           TikTok
# 999993   27    Male         UK           5.236780          Twitter
# 999998   24  Female    Germany           7.829924          YouTube
# 999999   13    Male     Canada           5.313645           TikTok
#
#         num_platforms_used           purpose  avg_session_minutes  \
# 1                        3       Socializing            32.464726
# ...

# %%
x['primary_platform'].value_counts(normalize=True)*100
# Out:
# primary_platform
# Instagram    30.029317
# YouTube      25.033036
# TikTok       24.999531
# Twitter       9.985810
# Snapchat      9.952305
# Name: proportion, dtype: float64

# %%
plt.pie(x['primary_platform'].value_counts(normalize=True), labels=x['primary_platform'].value_counts().index ,autopct ='%1.1f%%')
plt.title("App used by High addiction level people")

plt.show()

# %%
df.groupby('age')['daily_usage_hours'].mean()
# Out:
# age
# 13    3.518010
# 14    3.514019
# 15    3.510080
# 16    3.518551
# 17    3.522988
# 18    3.515588
# 19    3.521673
# 20    3.509077
# 21    3.513798
# 22    3.523681
# 23    3.505921
# 24    3.521699
# 25    3.516096
# 26    3.510184
# 27    3.503514
# Name: daily_usage_hours, dtype: float64

# %% [markdown]
# Demographic Insighsts

# %% [markdown]
#     Countries having highest social media usage

# %%
df.groupby("country")['daily_usage_hours'].mean().sort_values(ascending=False)
# Out:
# country
# UK           3.520975
# Brazil       3.520813
# Germany      3.517562
# Australia    3.516257
# India        3.515143
# Canada       3.510878
# USA          3.509319
# Name: daily_usage_hours, dtype: float64

# %% [markdown]
#     Gender wise social media consumption

# %%
df.groupby("gender")['daily_usage_hours'].mean().sort_values(ascending=False)
# Out:
# gender
# Other     3.520755
# Female    3.515354
# Male      3.514159
# Name: daily_usage_hours, dtype: float64

# %%
younger = df[df['age']<=25]
younger
# Out:
#         age  gender    country  daily_usage_hours primary_platform  \
# 0        19    Male  Australia           2.658617         Snapchat
# 1        16  Female        USA           5.685387          Twitter
# 2        25  Female      India           2.782420           TikTok
# 4        23  Female      India           3.748829           TikTok
# 5        20   Other     Brazil           2.932248           TikTok
# ...     ...     ...        ...                ...              ...
# 999995   21    Male      India           3.097065         Snapchat
# 999996   14    Male      India           3.663561        Instagram
# 999997   20    Male      India           4.474618          YouTube
# 999998   24  Female    Germany           7.829924          YouTube
# 999999   13    Male     Canada           5.313645           TikTok
#
#         num_platforms_used           purpose  avg_session_minutes  \
# 0                        4         Education            29.222443
# ...

# %%
older = df[df['age']>25]
older
# Out:
#         age  gender    country  daily_usage_hours primary_platform  \
# 3        27    Male      India           3.486598          YouTube
# 25       26    Male  Australia           5.595739        Instagram
# 40       27    Male        USA           2.939578         Snapchat
# 44       27    Male         UK           4.672093          YouTube
# 45       26  Female      India           2.623597        Instagram
# ...     ...     ...        ...                ...              ...
# 999966   27  Female    Germany           2.918980        Instagram
# 999970   27  Female      India           4.094375         Snapchat
# 999975   26  Female      India           3.480758           TikTok
# 999983   26  Female     Brazil           4.226685          Twitter
# 999993   27    Male         UK           5.236780          Twitter
#
#         num_platforms_used        purpose  avg_session_minutes  night_usage  \
# 3                        4      Education            22.493804            1
# ...

# %%
older['daily_usage_hours'].mean()
# Out:
# np.float64(3.50684108229549)

# %%
df.head()
# Out:
#    age  gender    country  daily_usage_hours primary_platform  \
# 0   19    Male  Australia           2.658617         Snapchat
# 1   16  Female        USA           5.685387          Twitter
# 2   25  Female      India           2.782420           TikTok
# 3   27    Male      India           3.486598          YouTube
# 4   23  Female      India           3.748829           TikTok
#
#    num_platforms_used        purpose  avg_session_minutes  night_usage  \
# 0                   4      Education            29.222443            0
# 1                   3    Socializing            32.464726            1
# 2                   2    Socializing            18.170204            1
# 3                   4      Education            22.493804            1
# 4                   1  Entertainment            27.358410            1
#
#    mental_health_score addiction_level  screen_time_before_sleep
# 0             6.705830          Medium                 15.779443
# ...

# %% [markdown]
#     Countries vs platform

# %%
pd.crosstab(df['country'], df['primary_platform'], normalize='index')*100
# Out:
# primary_platform  Instagram   Snapchat     TikTok    Twitter    YouTube
# country
# Australia         30.041780  10.147839  24.843323   9.892737  25.074321
# Brazil            30.039585   9.798859  25.120564  10.079171  24.961821
# Canada            30.002789  10.021517  25.173334   9.978682  24.823677
# Germany           29.858052  10.134540  25.072075  10.035437  24.899896
# India             30.017898   9.923185  24.994505   9.955155  25.109257
# UK                29.985151   9.923961  24.820864  10.151181  25.118842
# USA               29.978973   9.994993  24.997997   9.993992  25.034044

# %% [markdown]
#     Gender vs Platform

# %%
pd.crosstab(df['gender'], df['primary_platform'], normalize='index')*100
# Out:
# primary_platform  Instagram   Snapchat     TikTok    Twitter    YouTube
# gender
# Female            29.973360   9.928704  25.048478   9.991814  25.057643
# Male              29.999208   9.986113  24.976229  10.018224  25.020226
# Other             30.145618  10.205651  24.916276   9.935253  24.797202

# %% [markdown]
# Mental Health analysis

# %%
df.head()
# Out:
#    age  gender    country  daily_usage_hours primary_platform  \
# 0   19    Male  Australia           2.658617         Snapchat
# 1   16  Female        USA           5.685387          Twitter
# 2   25  Female      India           2.782420           TikTok
# 3   27    Male      India           3.486598          YouTube
# 4   23  Female      India           3.748829           TikTok
#
#    num_platforms_used        purpose  avg_session_minutes  night_usage  \
# 0                   4      Education            29.222443            0
# 1                   3    Socializing            32.464726            1
# 2                   2    Socializing            18.170204            1
# 3                   4      Education            22.493804            1
# 4                   1  Entertainment            27.358410            1
#
#    mental_health_score addiction_level  screen_time_before_sleep
# 0             6.705830          Medium                 15.779443
# ...

# %% [markdown]
#     Relationship between Daily Usage and Mental Health

# %%
df.groupby(pd.cut(df['daily_usage_hours'], bins=[0,2,4,6,10]))['mental_health_score'].mean()
# Out:
# daily_usage_hours
# (0, 2]     8.867244
# (2, 4]     7.537984
# (4, 6]     6.166419
# (6, 10]    4.700336
# Name: mental_health_score, dtype: float64

# %%
plt.scatter(df["daily_usage_hours"], df['mental_health_score'])
plt.xlabel("Daily Usage Hours")
plt.ylabel('Mental Health Score')
plt.title("Usage vs Mental Health")
plt.show()

# %% [markdown]
#         Platforms associated with Lower Mental Health

# %%
df.head()
# Out:
#    age  gender    country  daily_usage_hours primary_platform  \
# 0   19    Male  Australia           2.658617         Snapchat
# 1   16  Female        USA           5.685387          Twitter
# 2   25  Female      India           2.782420           TikTok
# 3   27    Male      India           3.486598          YouTube
# 4   23  Female      India           3.748829           TikTok
#
#    num_platforms_used        purpose  avg_session_minutes  night_usage  \
# 0                   4      Education            29.222443            0
# 1                   3    Socializing            32.464726            1
# 2                   2    Socializing            18.170204            1
# 3                   4      Education            22.493804            1
# 4                   1  Entertainment            27.358410            1
#
#    mental_health_score addiction_level  screen_time_before_sleep
# 0             6.705830          Medium                 15.779443
# ...

# %% [markdown]
#    Platform People having low mental health using?

# %%
a= df[df['mental_health_score']<=4]

# %%
a['primary_platform'].value_counts(normalize=True)*100
# Out:
# primary_platform
# Instagram    29.754358
# TikTok       25.188193
# YouTube      24.851426
# Snapchat     10.345681
# Twitter       9.860341
# Name: proportion, dtype: float64

# %% [markdown]
# Purpose Based Usage

# %%
df.head()
# Out:
#    age  gender    country  daily_usage_hours primary_platform  \
# 0   19    Male  Australia           2.658617         Snapchat
# 1   16  Female        USA           5.685387          Twitter
# 2   25  Female      India           2.782420           TikTok
# 3   27    Male      India           3.486598          YouTube
# 4   23  Female      India           3.748829           TikTok
#
#    num_platforms_used        purpose  avg_session_minutes  night_usage  \
# 0                   4      Education            29.222443            0
# 1                   3    Socializing            32.464726            1
# 2                   2    Socializing            18.170204            1
# 3                   4      Education            22.493804            1
# 4                   1  Entertainment            27.358410            1
#
#    mental_health_score addiction_level  screen_time_before_sleep
# 0             6.705830          Medium                 15.779443
# ...

# %% [markdown]
#     Purpose Of Using social media

# %%
a= df['purpose'].value_counts(normalize=True)*100
a
# Out:
# purpose
# Entertainment       40.0052
# Socializing         25.0239
# Education           20.0367
# News                 9.9693
# Content Creation     4.9649
# Name: proportion, dtype: float64

# %%
plt.bar(a.index, a.values , color= {'grey', "black"})
plt.title("Purpose of Usage")
plt.xlabel("Purpose")
plt.ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')

# %% [markdown]
#     Platform vs purpose breakdown

# %%
pd.crosstab(df['primary_platform'], df['purpose'] , normalize='index')*100
# Out:
# purpose           Content Creation  Education  Entertainment       News  \
# primary_platform
# Instagram                 4.947204  19.967859      39.946387   9.989431
# Snapchat                  4.848807  20.006220      40.334490   9.974517
# TikTok                    5.024692  20.067977      39.938421   9.949417
# Twitter                   5.002899  20.124573      40.001200   9.857831
# YouTube                   4.957410  20.064964      40.012865  10.007511
#
# purpose           Socializing
# primary_platform
# Instagram           25.149120
# Snapchat            24.835965
# TikTok              25.019493
# Twitter             25.013497
# YouTube             24.957250

# %%
df.head()
# Out:
#    age  gender    country  daily_usage_hours primary_platform  \
# 0   19    Male  Australia           2.658617         Snapchat
# 1   16  Female        USA           5.685387          Twitter
# 2   25  Female      India           2.782420           TikTok
# 3   27    Male      India           3.486598          YouTube
# 4   23  Female      India           3.748829           TikTok
#
#    num_platforms_used        purpose  avg_session_minutes  night_usage  \
# 0                   4      Education            29.222443            0
# 1                   3    Socializing            32.464726            1
# 2                   2    Socializing            18.170204            1
# 3                   4      Education            22.493804            1
# 4                   1  Entertainment            27.358410            1
#
#    mental_health_score addiction_level  screen_time_before_sleep
# 0             6.705830          Medium                 15.779443
# ...

# %% [markdown]
#     Mental health vs Purpose

# %%
df.groupby('purpose')['mental_health_score'].mean().sort_values(ascending=False)
# Out:
# purpose
# News                7.173848
# Education           7.173666
# Socializing         7.171299
# Entertainment       7.168832
# Content Creation    7.163853
# Name: mental_health_score, dtype: float64

# %%
df.groupby('night_usage')['mental_health_score'].mean()
# Out:
# night_usage
# 0    7.170899
# 1    7.170518
# Name: mental_health_score, dtype: float64

# %%
df.head()
# Out:
#    age  gender    country  daily_usage_hours primary_platform  \
# 0   19    Male  Australia           2.658617         Snapchat
# 1   16  Female        USA           5.685387          Twitter
# 2   25  Female      India           2.782420           TikTok
# 3   27    Male      India           3.486598          YouTube
# 4   23  Female      India           3.748829           TikTok
#
#    num_platforms_used        purpose  avg_session_minutes  night_usage  \
# 0                   4      Education            29.222443            0
# 1                   3    Socializing            32.464726            1
# 2                   2    Socializing            18.170204            1
# 3                   4      Education            22.493804            1
# 4                   1  Entertainment            27.358410            1
#
#    mental_health_score addiction_level  screen_time_before_sleep
# 0             6.705830          Medium                 15.779443
# ...

# %% [markdown]
# Risky Users who have high addiction with low mental score and high daily usage

# %%
risky_users= df[(df['daily_usage_hours']>5) & (df['addiction_level'] =='High') & (df['mental_health_score']<3) ]

# %% [markdown]
# Country having most risky people

# %%
risky_users['country'].value_counts(ascending=False)
# Out:
# country
# India        1201
# USA           686
# Germany       386
# UK            358
# Canada        343
# Brazil        334
# Australia     181
# Name: count, dtype: int64
